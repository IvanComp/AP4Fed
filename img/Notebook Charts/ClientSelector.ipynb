        [0.031129, 0.031488, 0.029632, 0.033442, 0.030917, 0.032241, 0.035645, 0.030515, 0.028661, 0.032591],
        [0.030309, 0.028264, 0.032787, 0.031816, 0.031399, 0.029642, 0.032338, 0.031372, 0.028078, 0.029373],
        [0.031734, 0.029022, 0.032126, 0.032949, 0.030382, 0.033299, 0.032639, 0.032095, 0.029155, 0.031576],
        [0.027048, 0.031303, 0.03391, 0.031404, 0.03094, 0.030881, 0.034805, 0.028711, 0.032819, 0.031704],
        [0.027469, 0.027441, 0.028952, 0.033131, 0.030957, 0.033039, 0.029585, 0.030392, 0.031726, 0.031241],
    ],
    "C": [
        [0.092407, 0.094286, 0.090733, 0.106823, 0.106374, 0.099493, 0.107952, 0.106113, 0.101707, 0.109513],
        [0.158116, 0.155883, 0.162171, 0.155852, 0.173072, 0.185932, 0.15343, 0.157152, 0.167384, 0.182578],
        [0.191683, 0.200289, 0.182571, 0.187793, 0.222757, 0.218605, 0.182, 0.219163, 0.204537, 0.214717],
        [0.216027, 0.219683, 0.216516, 0.227342, 0.203217, 0.199319, 0.211549, 0.226924, 0.20406, 0.226596],
        [0.260368, 0.219588, 0.248285, 0.238289, 0.257671, 0.223568, 0.249246, 0.257297, 0.260253, 0.246723],
        [0.237866, 0.245657, 0.258781, 0.245418, 0.216553, 0.260686, 0.250135, 0.247437, 0.224466, 0.24969],
        [0.242736, 0.256531, 0.23033, 0.258924, 0.273871, 0.227411, 0.272763, 0.245345, 0.268538, 0.265176],
        [0.251324, 0.261922, 0.270001, 0.245207, 0.241352, 0.257346, 0.266454, 0.263114, 0.263831, 0.246779],
        [0.263765, 0.23101, 0.253233, 0.225288, 0.242194, 0.24235, 0.244809, 0.259773, 0.24345, 0.248424],
        [0.253932, 0.263156, 0.254327, 0.247867, 0.275586, 0.27805, 0.277476, 0.268029, 0.262532, 0.287475],
    ],
}

# Accuracy Graph
fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(rounds, accuracy_P1, label="Config. A", color="#1f77b4", marker="o", linewidth=2, linestyle="-", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in accuracy_simulated["A"]], [max(sim) for sim in accuracy_simulated["A"]], color="#1f77b4", alpha=0.2)
ax1.plot(rounds, accuracy_P1_prime, label="Config. B", color="#d62728", marker="s", linewidth=2, linestyle="--", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in accuracy_simulated["B"]], [max(sim) for sim in accuracy_simulated["B"]], color="#d62728", alpha=0.2)
ax1.plot(rounds, accuracy_P1_excluded, label="Config. C", color="#2ca02c", marker="^", linewidth=2, linestyle=":", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in accuracy_simulated["C"]], [max(sim) for sim in accuracy_simulated["C"]], color="#2ca02c", alpha=0.2)
ax1.set_xlabel("Federated Learning Round", fontsize=33)
ax1.set_ylabel("F1 Score", fontsize=33)
ax1.tick_params(axis="both", labelsize=33)
ax1.set_xticks(rounds)
fig.legend(fontsize=25, loc="upper center", bbox_to_anchor=(0.56, 1.11), ncol=3)
plt.tight_layout()
plt.savefig("ClientSelector1.pdf", bbox_inches="tight")
plt.show()

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(rounds, time_P1, label="Config. A", color="#1f77b4", marker="o", linewidth=2, linestyle="-", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in time_simulated["A"]], [max(sim) for sim in time_simulated["A"]], color="#1f77b4", alpha=0.2)
ax1.plot(rounds, time_P1_prime, label="Config. B", color="#d62728", marker="s", linewidth=2, linestyle="--", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in time_simulated["B"]], [max(sim) for sim in time_simulated["B"]], color="#d62728", alpha=0.2)
ax1.plot(rounds, time_P1_excluded, label="Config. C", color="#2ca02c", marker="^", linewidth=2, linestyle=":", solid_capstyle="round")
ax1.fill_between(rounds, [min(sim) for sim in time_simulated["C"]], [max(sim) for sim in time_simulated["C"]], color="#2ca02c", alpha=0.2)
ax1.set_xlabel("Federated Learning Round", fontsize=33)
ax1.set_ylabel("Total Round Time (sec)", fontsize=33)
ax1.tick_params(axis="both", labelsize=33)
ax1.set_xticks(rounds)
fig.legend(fontsize=25, loc="upper center", bbox_to_anchor=(0.56, 1.11), ncol=3)
plt.tight_layout()
plt.savefig("ClientSelector2.pdf", bbox_inches="tight")
plt.show()

# Efficiency Graph
fig, ax3 = plt.subplots(figsize=(10, 6))
ax3.plot(rounds, efficiency_P1, label="Config. A", color="#1f77b4", marker="o", linewidth=2, linestyle="-", solid_capstyle="round")
ax3.fill_between(rounds, [min(sim) for sim in efficiency_simulated["A"]], [max(sim) for sim in efficiency_simulated["A"]], color="#1f77b4", alpha=0.2)
ax3.plot(rounds, efficiency_P1_prime, label="Config. B", color="#d62728", marker="s", linewidth=2, linestyle="--", solid_capstyle="round")
ax3.fill_between(rounds, [min(sim) for sim in efficiency_simulated["B"]], [max(sim) for sim in efficiency_simulated["B"]], color="#d62728", alpha=0.2)
ax3.plot(rounds, efficiency_P1_excluded, label="Config. C", color="#2ca02c", marker="^", linewidth=2, linestyle=":", solid_capstyle="round")
ax3.fill_between(rounds, [min(sim) for sim in efficiency_simulated["C"]], [max(sim) for sim in efficiency_simulated["C"]], color="#2ca02c", alpha=0.2)
ax3.set_xlabel("Federated Learning Round", fontsize=33)
ax3.set_ylabel("F1 Score / Total Round Time", fontsize=33)
ax3.tick_params(axis="both", labelsize=33)
ax3.set_xticks(rounds)
fig.legend(fontsize=25, loc="upper center", bbox_to_anchor=(0.56, 1.11), ncol=3)
plt.tight_layout()
plt.savefig("ClientSelector3.pdf", bbox_inches="tight")
plt.show()
