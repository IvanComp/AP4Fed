# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# Define the rounds
rounds = np.arange(1, 11)
plt.rcParams['font.family'] = 'CMU Serif'

# Only keep Config D (renamed to A) and Combined
accuracy_A = [0.11, 0.13, 0.16, 0.18, 0.19, 0.21, 0.22, 0.22, 0.24, 0.25]  
accuracy_Combined = [0.11, 0.12, 0.15, 0.17, 0.19, 0.20, 0.20, 0.22, 0.23, 0.24]

total_round_time_A = [463, 482, 495, 478, 502, 517, 486, 491, 508, 497] 
total_round_time_Combined = [480, 496, 499, 495, 505, 510, 500, 496, 510, 499]

# Calculate Accuracy over Total Round Time and multiply by 1000
accuracy_over_time_A = [1000 * (a / t) for a, t in zip(accuracy_A, total_round_time_A)]
accuracy_over_time_Combined = [1000 * (a / t) for a, t in zip(accuracy_Combined, total_round_time_Combined)]

# Colors and styles
colors = ['#2ca02c', '#1f77b4']
labels = ['Config. A', 'Config. Combined']
markers = ['d', 'o']

### First Plot: F1 Score with Confidence Intervals ###
fig1, ax1 = plt.subplots(figsize=(14, 10))

# Define confidence intervals
ci_A = [0.006] * len(accuracy_A)
ci_Combined = [0.003] * len(accuracy_Combined)

for i, (data, label, color, marker, ci) in enumerate(zip(
    [accuracy_A, accuracy_Combined],
    labels, colors, markers, [ci_A, ci_Combined]
)):
    linestyle = '-' if label == 'Config. Combined' else '--'
    ax1.plot(rounds, data, color=color, label=label, marker=marker, linewidth=2, linestyle=linestyle)
    ax1.fill_between(rounds, 
                     [d - c for d, c in zip(data, ci)], 
                     [d + c for d, c in zip(data, ci)], 
                     color=color, alpha=0.2)

ax1.set_xlabel('Federated Learning Round', fontsize=30)
ax1.set_ylabel('F1 Score', fontsize=30)
ax1.tick_params(axis='both', labelsize=30)
ax1.set_xticks(rounds)
ax1.legend(fontsize=25, loc='upper center', bbox_to_anchor=(0.5, 1.11), ncol=2)
plt.savefig('HDH1_Combined.pdf', bbox_inches='tight')
plt.show()

### Second Plot: Total Round Time with Confidence Intervals ###
fig2, ax2 = plt.subplots(figsize=(14, 10))

ci_A = [10] * len(total_round_time_A)
ci_Combined = [10] * len(total_round_time_Combined)

for i, (data, label, color, marker, ci) in enumerate(zip(
    [total_round_time_A, total_round_time_Combined],
    labels, colors, markers, [ci_A, ci_Combined]
)):
    linestyle = '-' if label == 'Config. Combined' else '--'
    ax2.plot(rounds, data, color=color, label=label, marker=marker, linewidth=2, linestyle=linestyle)
    ax2.fill_between(rounds, 
                     [d - c for d, c in zip(data, ci)], 
                     [d + c for d, c in zip(data, ci)], 
                     color=color, alpha=0.2)

ax2.set_xlabel('Federated Learning Round', fontsize=30)
ax2.set_ylabel('Total Round Time (sec)', fontsize=30)
ax2.tick_params(axis='both', labelsize=30)
ax2.set_xticks(rounds)
ax2.legend(fontsize=25, loc='upper center', bbox_to_anchor=(0.5, 1.11), ncol=2)
plt.savefig('HDH2_Combined.pdf', bbox_inches='tight')
plt.show()

### Third Plot: F1 Score / Total Round Time with Confidence Intervals ###
fig3, ax3 = plt.subplots(figsize=(14, 10))

ci_A = [0.01, 0.012, 0.011, 0.013, 0.01, 0.012, 0.009, 0.011, 0.0125, 0.01]
ci_Combined = [0.01, 0.012, 0.011, 0.013, 0.01, 0.012, 0.009, 0.011, 0.0125, 0.01]

for i, (data, label, color, marker, ci) in enumerate(zip(
    [accuracy_over_time_A, accuracy_over_time_Combined],
    labels, colors, markers, [ci_A, ci_Combined]
)):
    linestyle = '-' if label == 'Config. Combined' else '--'
    ax3.plot(rounds, data, color=color, label=label, marker=marker, linewidth=2, linestyle=linestyle)
    ax3.fill_between(rounds, 
                     [d - c for d, c in zip(data, ci)], 
                     [d + c for d, c in zip(data, ci)], 
                     color=color, alpha=0.2)

ax3.set_xlabel('Federated Learning Round', fontsize=30)
ax3.set_ylabel('F1 Score / Total Round Time', fontsize=30)
ax3.tick_params(axis='both', labelsize=30)
ax3.set_xticks(rounds)
ax3.legend(fontsize=25, loc='upper center', bbox_to_anchor=(0.5, 1.11), ncol=2)

plt.savefig('HDH3_Combined.pdf', bbox_inches='tight')
plt.show()
